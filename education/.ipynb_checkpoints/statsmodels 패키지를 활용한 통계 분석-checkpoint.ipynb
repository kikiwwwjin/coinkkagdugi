# %%
# 패키지 임포트
import pandas as pd
import numpy as np
from scipy.stats import shapiro, normaltest, kstest

import matplotlib.pyplot as plt # 데이터 시각화 패키지 1
import seaborn as sns # 데이터 시각화 패키지 2

# %%
# 실습 데이터 불러오기
# df = pd.read_csv('C:\\Users\\wai\\Desktop\\프로젝트\\교육자료\\교육데이터\\kaggle\\aug_train.csv')
# test_df = pd.read_csv('C:\\Users\\wai\\Desktop\\프로젝트\\교육자료\\교육데이터\\kaggle\\aug_test.csv') # 테스트 데이터
df = pd.read_csv('D:\\kaggle\\aug_train.csv') # 학습 데이터
test_df = pd.read_csv('D:\\kaggle\\aug_test.csv') # 테스트 데이터
print('학습데이터\n', df, '\n 테스트 데이터\n', test_df)
# Out:
# 학습데이터
#              id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0       167647    Male   22                1          7.0                   1
# 1        17163    Male   42                1         28.0                   0
# 2        32023  Female   66                1         33.0                   0
# 3        87447  Female   22                1         33.0                   0
# 4       501933    Male   28                1         46.0                   1
# ...        ...     ...  ...              ...          ...                 ...
# 382149  164549    Male   24                1         15.0                   0
# 382150  247064    Male   27                1         28.0                   1
# 382151  165293    Male   45                1         28.0                   0
# 382152  383241  Female   28                1         28.0                   1
# 382153  401019  Female   29                1         18.0                   1
#
#        Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 0         < 1 Year             No          2630.0                 152.0
# 1         1-2 Year            Yes         43327.0                  26.0
# 2         1-2 Year            Yes         35841.0                 124.0
# 3         < 1 Year             No         27645.0                 152.0
# 4         < 1 Year             No         29023.0                 152.0
# ...            ...            ...             ...                   ...
# 382149    < 1 Year            Yes         23938.0                 152.0
# 382150    < 1 Year             No        336395.0                 152.0
# 382151    1-2 Year            Yes         40443.0                  26.0
# 382152    < 1 Year             No         25380.0                 152.0
# 382153    < 1 Year             No         30396.0                 152.0
#
#         Vintage  Response
# 0            16         0
# 1           135         0
# 2           253         0
# 3            69         0
# 4           211         0
# ...         ...       ...
# 382149      105         0
# 382150      144         0
# 382151      187         0
# 382152      208         0
# 382153      104         0
#
# [382154 rows x 12 columns]
#  테스트 데이터
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0       57782  Female   34                1         39.0                   1
# 1      286811  Female   55                1         28.0                   0
# 2      117823    Male   39                1         28.0                   1
# 3      213992    Male   28                1         50.0                   1
# 4      324756  Female   24                1         10.0                   0
# ...       ...     ...  ...              ...          ...                 ...
# 78268     847    Male   43                1         39.0                   0
# 78269  417524  Female   21                1         12.0                   1
# 78270  188087    Male   48                1         29.0                   1
# 78271  215680    Male   64                1          5.0                   1
# 78272  138006  Female   25                1         41.0                   1
#
#       Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 0        1-2 Year             No         38244.0                 124.0
# 1       > 2 Years            Yes         37577.0                 122.0
# 2        1-2 Year             No         24578.0                  26.0
# 3        1-2 Year             No         40507.0                   8.0
# 4        < 1 Year            Yes         36783.0                 152.0
# ...           ...            ...             ...                   ...
# 78268    1-2 Year            Yes          2630.0                 124.0
# 78269    < 1 Year             No         32937.0                 152.0
# 78270    1-2 Year             No         35247.0                 124.0
# 78271    1-2 Year             No         25705.0                  26.0
# 78272    < 1 Year             No         27752.0                 152.0
#
#        Vintage
# 0          146
# 1          109
# 2           63
# 3          129
# 4          201
# ...        ...
# 78268       26
# 78269      185
# 78270      101
# 78271       86
# 78272      235
#
# [78273 rows x 11 columns]

# %%
### 실습 1) 정규성 검정
# 참고문헌 : https://alex-blog.tistory.com/entry/t-test-ANOVA-%EC%89%BD%EA%B2%8C%EC%89%BD%EA%B2%8C-%EA%B8%B0%EC%96%B5%ED%95%98%EC%9E%90
from statsmodels.stats.diagnostic import kstest_normal
from statsmodels.stats.stattools import omni_normtest, jarque_bera

# 검정 대상 변수 : 'Vintage'
print('검정 대상 변수 \n', df.loc[:,'Vintage'])
# 실습 1-1) 콜모고로프-스미르노프 검정(Kolmogorov-Smirnov test)
print('콜모고로프-스미르노프 검정 :', kstest_normal(df.loc[:,'Vintage']))
# 실습 1-2) 옴니버스 검정(Omnibus Normality test)
print('옴니버스 검정 :', omni_normtest(df.loc[:,'Vintage']))
# 실습 1-3) 자크-베라 검정(Jarque–Bera test)
print('자크-베라 검정 :', jarque_bera(df.loc[:,'Vintage']))
# Out:
# 검정 대상 변수
#  0          16
# 1         135
# 2         253
# 3          69
# 4         211
#          ...
# 382149    105
# 382150    144
# 382151    187
# 382152    208
# 382153    104
# Name: Vintage, Length: 382154, dtype: int64
# 콜모고로프-스미르노프 검정 : (0.059590590452055614, 0.0)
# 옴니버스 검정 : NormaltestResult(statistic=347636.69136850606, pvalue=0.0)
# 자크-베라 검정 : (23028.60438677085, 0.0, 0.004005278481872692, 1.797429376725579)

# %%
### 선형 회귀 분석

# 일반적인 가정 : 선형성, 독립성, 등분산성, 정규성
# 가정 : 정규분포(한쪽으로 쏠리면 정확한 결과 값을 도출하기 힘듬), 독립변수는 독립적인 형태여야함(공분산)

# 공분산(covariance) : 두 변수가 함께 변화하는 정도를 나타내는 지표 => 특정변수(X)의 편차와 다른 변수(Y)의 편차를 곱한것의 평균
  # => 이러한 수식은 단위에 영향을 받음 단위가 크면 공분산 값도 클수 밖에 없는 수식임
  # => 이것 때문에 상관계수(Correlation)이 나타남(상관계수는 절대적 크기에 영향을 받지 않음)
print(df)
print(df.columns)

# 종속변수(TARGET) : 'Age'
# 독립변수(Input Data) : 'Region_Code', 'Annual_Premium', 'Policy_Sales_Channel', 'Vintage'

# 
for
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0       381110    Male   25                1         11.0                   1
# 1       381111    Male   40                1         28.0                   0
# 2       381112    Male   47                1         28.0                   0
# 3       381113    Male   24                1         27.0                   1
# 4       381114    Male   27                1         28.0                   1
# ...        ...     ...  ...              ...          ...                 ...
# 127032  508142  Female   26                1         37.0                   1
# 127033  508143  Female   38                1         28.0                   0
# 127034  508144    Male   21                1         46.0                   1
# 127035  508145    Male   71                1         28.0                   1
# 127036  508146    Male   41                1         29.0                   1
#
#        Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 0         < 1 Year             No         35786.0                 152.0
# 1         1-2 Year            Yes         33762.0                   7.0
# 2         1-2 Year            Yes         40050.0                 124.0
# 3         < 1 Year            Yes         37356.0                 152.0
# 4         < 1 Year             No         59097.0                 152.0
# ...            ...            ...             ...                   ...
# 127032    < 1 Year             No         30867.0                 152.0
# 127033    1-2 Year            Yes         28700.0                 122.0
# 127034    < 1 Year             No         29802.0                 152.0
# 127035    1-2 Year             No         62875.0                  26.0
# 127036    1-2 Year             No         27927.0                 124.0
#
#         Vintage
# 0            53
# 1           111
# 2           199
# 3           187
# 4           297
# ...         ...
# 127032       56
# 127033      165
# 127034       74
# 127035      265
# 127036      231
#
# [127037 rows x 11 columns]
# Index(['id', 'Gender', 'Age', 'Driving_License', 'Region_Code',
#        'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium',
#        'Policy_Sales_Channel', 'Vintage'],
#       dtype='object')

# %%
### 실습 2) 상관관계 검정
# Pearson, Spearman 상관계수는 -1 ~ +1 범위의 값, Pearson 상관 계수가 +1이 되도록 하기 위해 한 변수가 증가하면 다른 변수가 일정한 양만큼 증가합니다.
# => 이 관계는 완전한 선을 형성합니다. 이 경우 Spearman 상관 계수도 +1 입니다.
# 상관계수가 0이면 두 변수가 독립관계입니다. 예측이 불가능한 관계


# 패키지 임포트
from scipy.stats import spearmanr, pearsonr

# 독립변수 및 종속변수 선정
var_tgt = 'Age' # 종속변수
inp_var_list = ['Region_Code', 'Annual_Premium', 'Policy_Sales_Channel', 'Vintage'] # 독립변수 리스트
# spearmanr().correlation

# for 문으로 종속변수('Age')에 대한 독립변수 리스트 상관 관계 검정
for var in inp_var_list:
    print('#'*40)
    print('독립변수명 :',var)
    sprmn_cor = spearmanr(df[var], df[var_tgt])
    prsn_cor = pearsonr(df[var], df[var_tgt])
    print('피어슨 상관계수 :', prsn_cor, ', 스피어만 상관계수', sprmn_cor)

    # 1000건 샘플 plot 그래프
    sample_df = df[[var, var_tgt]].sample(n=10000)
    sns.pairplot(sample_df, kind='reg', height=4)
    plt.show()
# Out:
# ########################################
# 독립변수명 : Region_Code
# 피어슨 상관계수 : (0.04372799913674179, 4.386820671497693e-161) , 스피어만 상관계수 SpearmanrResult(correlation=0.01240077772057871, pvalue=1.7708744399783038e-14)
# ########################################
# 독립변수명 : Annual_Premium
# 피어슨 상관계수 : (0.06509039703591309, 0.0) , 스피어만 상관계수 SpearmanrResult(correlation=0.09875043392746904, pvalue=0.0)
# ########################################
# 독립변수명 : Policy_Sales_Channel
# 피어슨 상관계수 : (-0.582299767335632, 0.0) , 스피어만 상관계수 SpearmanrResult(correlation=-0.6518105502961126, pvalue=0.0)
# ########################################
# 독립변수명 : Vintage
# 피어슨 상관계수 : (0.0006691648530549568, 0.6791179423795487) , 스피어만 상관계수 SpearmanrResult(correlation=0.00022035500808732897, pvalue=0.8916474047587104)

# %%
# 실습 3) 커널 밀도 추정
# 히스토그램과 같이 비모수 추정일 경우 불연속이라는 단점이 있지만, 부드러운(Smooth) 형태의 밀도함수를 추정하기 위해 사각형 kernel 대신 사용합니다.

# 패키지 임포트
from scipy.stats import gaussian_kde

# 가우시안 커널 밀도 
kernel = gaussian_kde(df['Age'], bw_method='silverman')
age_min = df['Age'].min()
age_max = df['Age'].max()
X = np.arange(age_min, age_max, 1)
K = kernel(X)
# RAW 데이터의 확률밀도 히스토그램
plt.hist(df['Age'], label='Original_Prob_Density', density=True)
# 가우시안 커널 밀도 추정
plt.plot(X, K, label='gaussian_kde')
plt.legend()
plt.show()

# %%
# 실습 4) 회귀 분석(Linear Regression)
# 참고문헌 : https://brunch.co.kr/@gimmesilver/38, https://ysyblog.tistory.com/119, https://riverzayden.tistory.com/10
# 4-1) 선형 모형(Linear Model)
import statsmodels.api as sm

model = sm.OLS.from_formula('Age ~ ' + '+'.join(inp_var_list), df).fit()
print(model.summary()) # 모델에 대한 정보 출력
# 유의미한 변수 확인 => P>|t| 값이 0.05보다 작으면 유의미한 변수
p_vars = model.pvalues.index[model.pvalues <= 0.05]
p_vars = list(p_vars[1:]) # 첫번째 변수는 Intercept(절편)으로 제외

# 유의미한 변수로 재학습
model = sm.OLS.from_formula('Age ~ ' + '+'.join(p_vars), df).fit()
pred_df = model.predict(test_df) # 종속변수(나이) 예측값
test_df['Age_Pred'] = pred_df
test_df = test_df.astype({'Age_Pred' : int}) # 정수 값으로 변환(소수점 제거)
print('결과 데이터 :\n',test_df)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    Age   R-squared:                       0.339
# Model:                            OLS   Adj. R-squared:                  0.339
# Method:                 Least Squares   F-statistic:                 4.910e+04
# Date:                Tue, 20 Jul 2021   Prob (F-statistic):               0.00
# Time:                        01:07:10   Log-Likelihood:            -1.5036e+06
# No. Observations:              382154   AIC:                         3.007e+06
# Df Residuals:                  382149   BIC:                         3.007e+06
# Df Model:                           4
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept               56.2671      0.083    674.148      0.000      56.104      56.431
# Region_Code              0.0223      0.002     14.693      0.000       0.019       0.025
# Annual_Premium       -1.362e-06   1.18e-06     -1.153      0.249   -3.68e-06    9.53e-07
# Policy_Sales_Channel    -0.1632      0.000   -439.079      0.000      -0.164      -0.162
# Vintage              -4.045e-05      0.000     -0.169      0.866      -0.001       0.000
# ==============================================================================
# Omnibus:                    51188.577   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            76841.225
# Skew:                           0.982   Prob(JB):                         0.00
# Kurtosis:                       3.985   Cond. No.                     1.46e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.46e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 결과 데이터 :
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0       57782  Female   34                1         39.0                   1
# 1      286811  Female   55                1         28.0                   0
# 2      117823    Male   39                1         28.0                   1
# 3      213992    Male   28                1         50.0                   1
# 4      324756  Female   24                1         10.0                   0
# ...       ...     ...  ...              ...          ...                 ...
# 78268     847    Male   43                1         39.0                   0
# 78269  417524  Female   21                1         12.0                   1
# 78270  188087    Male   48                1         29.0                   1
# 78271  215680    Male   64                1          5.0                   1
# 78272  138006  Female   25                1         41.0                   1
#
#       Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 0        1-2 Year             No         38244.0                 124.0
# 1       > 2 Years            Yes         37577.0                 122.0
# 2        1-2 Year             No         24578.0                  26.0
# 3        1-2 Year             No         40507.0                   8.0
# 4        < 1 Year            Yes         36783.0                 152.0
# ...           ...            ...             ...                   ...
# 78268    1-2 Year            Yes          2630.0                 124.0
# 78269    < 1 Year             No         32937.0                 152.0
# 78270    1-2 Year             No         35247.0                 124.0
# 78271    1-2 Year             No         25705.0                  26.0
# 78272    < 1 Year             No         27752.0                 152.0
#
#        Vintage  Age_Pred
# 0          146        36
# 1          109        36
# 2           63        52
# 3          129        56
# 4          201        31
# ...        ...       ...
# 78268       26        36
# 78269      185        31
# 78270      101        36
# 78271       86        52
# 78272      235        32
#
# [78273 rows x 12 columns]
